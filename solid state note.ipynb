# %% [markdown]
# # Title: Solid state physics

# %% [markdown]
# ## Subtitle: Crystal Structures

# %% [markdown]
# ### SubSubTitle: FCC

# %% [markdown]
# $d_{hkl}=\frac{a}{\sqrt{h^2+k^2+l^2}}$

# %%
print('hello world Prakash')
# Out:
# hello world Prakash

# %% [markdown]
# $y=mx+c$

# %% [markdown]
# $f=\frac{GMm}{r^{2}}$

# %%
$\thita$
# Out:
#   File "<ipython-input-2-47f51d57a92c>", line 1
#     $\thita$
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# $\alpha$

# %% [markdown]
# $\{alpha}$

# %% [markdown]
# $\alpha$

# %%
inporty numpy as
$x=np.log(5)$
x
# Out:
#   File "<ipython-input-6-0454b6649aaf>", line 1
#     inporty numpy as
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![img]-(https://www.google.com/url?sa=i&url=https%3A%2F%2Fyourstory.com%2Fweekender%2Ffamous-quotes-albert-einstein-physicist-birthday&psig=AOvVaw3mlrisB7nxDG37pgVdox-v&ust=1594050396780000&source=images&cd=vfe&ved=0CAIQjRxqFwoTCIChxdG6tuoCFQAAAAAdAAAAABAD)

# %% [markdown]
# ![img]data:image/jpeg;base64,...()

# %% [markdown]
# ![img](data:image/jpeg;base64,...)

# %% [markdown]
# ![img] (PYTHON.png)

# %% [markdown]
# ! [img](CV,docx)
